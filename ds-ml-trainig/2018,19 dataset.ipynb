# %% [markdown]
# # Number of Startups in 2018

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('startup_funding2018.csv')
#df['CityLocation'].dropna(inplace=True)
df.dropna(subset=["Location"],inplace=True)

def separateCity(city): 
    return city.split('/')[0].strip() 
df['Location']=df['Location'].apply(separateCity) 
df[df['Location']=='bangalore'] = 'Bangalore'
df[df['Location']=='Delhi'] = 'New Delhi'

city = df['Location']
city = city.value_counts()[:10]
city_name = city.index
no_of_str = city.values

plt.pie(no_of_str, labels=city_name, autopct='%.2f%%',counterclock=False)
plt.title('Number of startup in city')
plt.axis("equal")
plt.show()

for i in range(city_name.shape[0]):
    print(city_name[i],no_of_str[i])
# Out:
# Bangalore, Karnataka, India 102
# Mumbai, Maharashtra, India 94
# Bengaluru, Karnataka, India 55
# Gurgaon, Haryana, India 52
# New Delhi, Delhi, India 51
# Pune, Maharashtra, India 20
# Chennai, Tamil Nadu, India 19
# Hyderabad, Andhra Pradesh, India 18
# Delhi, Delhi, India 16
# Noida, Uttar Pradesh, India 15

# %% [markdown]
# # NUMBER OF STARTUPS IN 2019

# %%
#for 2019

df = pd.read_csv('archive/startup_funding2019.csv')
#df['CityLocation'].dropna(inplace=True)
df.dropna(subset=["HeadQuarter"],inplace=True)

def separateCity(city): 
    return city.split('/')[0].strip() 
df['HeadQuarter']=df['HeadQuarter'].apply(separateCity) 
df[df['HeadQuarter']=='bangalore'] = 'Bangalore'
df[df['HeadQuarter']=='Delhi'] = 'New Delhi'

city = df['HeadQuarter']
city = city.value_counts()[:10]
city_name = city.index
no_of_str = city.values

plt.pie(no_of_str, labels=city_name, autopct='%.2f%%',counterclock=False)
plt.title('Number of startup in city')
plt.axis("equal")
plt.show()

for i in range(city_name.shape[0]):
    print(city_name[i],no_of_str[i])
# Out:
# Bangalore 21
# Mumbai 12
# New Delhi 11
# Noida 5
# Gurugram 5
# Chennai 4
# Pune 2
# Jaipur 2
# Telangana 1
# Ahmedabad 1

# %%
import csv
import matplotlib.pyplot as plt

import collections
with open('startup_funding2018.csv') as file_obj:
    file_data = csv.DictReader(file_obj, skipinitialspace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 14
#      11 plt.title('Year VS "Number of Fundings"')
#      12 plt.show()
# ---> 14 for i in ord_dct.keys():
#      15     print(i,end=" ")
#      16     print(ord_dct[i])
#
# NameError: name 'ord_dct' is not defined

# %%
import pandas as pd
import numpy as np




df = pd.read_csv('startup_funding2018.csv')
#df['CityLocation'].dropna(inplace=True)
df.dropna(subset=["Location"],inplace=True)

def separateCity(city): 
    return city.split('/')[0].strip() 
df['Location']=df['Location'].apply(separateCity) 


city = df['Location']
city = city.value_counts()[:10]
city_name = city.index
no_of_str = city.values

plt.pie(no_of_str, labels=city_name, autopct='%.2f%%',counterclock=False)
plt.title('Number of startup in city')
plt.axis("equal")
plt.show()

for i in range(city_name.shape[0]):
    print(city_name[i],no_of_str[i])
# Out:
# Bangalore, Karnataka, India 102
# Mumbai, Maharashtra, India 94
# Bengaluru, Karnataka, India 55
# Gurgaon, Haryana, India 52
# New Delhi, Delhi, India 51
# Pune, Maharashtra, India 20
# Chennai, Tamil Nadu, India 19
# Hyderabad, Andhra Pradesh, India 18
# Delhi, Delhi, India 16
# Noida, Uttar Pradesh, India 15

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



df = pd.read_csv('startup_funding2018.csv')
df.dropna(subset=["Location"],inplace=True)
def separateCity(city):
    return city.split('/')[0].strip()
df['Location'] = df['Location'].apply(separateCity)


df['Amount'] = df['Amount'].apply(lambda x: float(str(x).replace(",","")))
df = df.groupby('Location')['Amount'].sum()
df = df.sort_values(ascending = False)[0:10]
city = df.index
amount = df.values
explode = [0.4,0.5,0.6,0.2,0.1,0.1,0.2,0.3,0.4,0.1]
plt.pie(amount,labels = city,autopct='%0.2f',counterclock=False,startangle=90,explode =explode,radius=1.5)
plt.show()

percent = np.true_divide(amount,amount.sum())*100
for i in range(len(city)):
    print(city[i],format(percent[i],'0.2f'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [17], line 14
#      10     return city.split('/')[0].strip()
#      11 df['Location'] = df['Location'].apply(separateCity)
# ---> 14 df['Amount'] = df['Amount'].apply(lambda x: float(str(x).replace(",","")))
#      15 df = df.groupby('Location')['Amount'].sum()
#      16 df = df.sort_values(ascending = False)[0:10]
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/apply.py:1105, in SeriesApply.apply(self)
#    1102     return self.apply_str()
#    1104 # self.f is Callable
# -> 1105 return self.apply_standard()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/apply.py:1156, in SeriesApply.apply_standard(self)
#    1154     else:
#    1155         values = obj.astype(object)._values
# -> 1156         mapped = lib.map_infer(
#    1157             values,
#    1158             f,
#    1159             convert=self.convert_dtype,
#    1160         )
#    1162 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1163     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1164     #  See also GH#25959 regarding EA support
#    1165     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2918, in pandas._libs.lib.map_infer()
#
# Cell In [17], line 14, in <lambda>(x)
#      10     return city.split('/')[0].strip()
#      11 df['Location'] = df['Location'].apply(separateCity)
# ---> 14 df['Amount'] = df['Amount'].apply(lambda x: float(str(x).replace(",","")))
#      15 df = df.groupby('Location')['Amount'].sum()
#      16 df = df.sort_values(ascending = False)[0:10]
#
# ValueError: could not convert string to float: '₹40000000'
